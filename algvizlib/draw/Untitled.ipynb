# %%
from graphviz import Graph
from IPython import display

g1 = Graph(format='svg')
g1.node('n1')
g1.node('n2')
display.display(g1)

# %%
g1.node('n1', color='red')
g1.edge('n1', 'n2')
display.display(g1)
